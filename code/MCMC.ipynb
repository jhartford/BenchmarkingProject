# %%
using Distributions: Normal, Uniform, pdf
using PyPlot
using Gadfly
include("mcmc.jl")
include("utils.jl")
include("SMCSampler.jl")
# Out:
# smcsampler (generic function with 1 method)

# %% [markdown]
# # Target distribution

# %%
p(x, alpha = 1.0) = (exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
p_dist(x, alpha = 1.0) = 1/((1.5+sqrt(2))*sqrt(pi))*(exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1));
plot([p], -5, 20)
# Out:
# Plot(...)

# %% [markdown]
# ## Ground Truth
# ### Wolfram Alpha
# ![Expected Value](ex.png)
# ![Expected Value](ex2.png)
#
# ### MCMC
# Estimated with $10^8$ samples
# $$\mu = 4.055412394948941$$
# $$E[x^2] = 46.20034183182638$$
# $$\sigma = 29.753972138720876$$

# %%
e_x = 4.05887;
e_x2 = 46.2633;

# %% [markdown]
# # MCMC

# %% [markdown]
# Get the samples...

# %%
srand(1236)
x0 = rand(); #starting position
n = int(1e6); #number of samples
@time x = mcmc(p, x0, n = n, stype = Float32, sig = 15);
# Out:
# elapsed time: 0.
# 686223464 seconds (104791392 bytes allocated, 20.70% gc time)

# %% [markdown]
# Plot the output

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("MCMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x10e0b1d90>)
# PyObject <matplotlib.text.Text object at 0x10e902290>

# %% [markdown]
# ### Evaluate performance

# %%
println(mean(x));
println(mean(x.^2));
g(x) = x.^2;
diff_x = fast_means(x);
diff_x2 = fast_means(x, g);
stable_x = stabalise(diff_x, e_x)
# Out:
# 4.
# 0596705506911235
# 46.21261922786536
# 226887

# %%
plt.plot(1:n, diff_x)
plt.plot((1, n), (e_x, e_x))
plt.plot((1, n), (e_x*1.01, e_x*1.01))
plt.plot((1, n), (e_x*0.99, e_x*0.99))
plt.plot((stable_x, stable_x), (0, e_x*20))
ylim(e_x*0.98, e_x*1.02)
title("Convergence of E[x]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1167a1950>)
# PyObject <matplotlib.text.Text object at 0x1193c3590>

# %%
plt.plot(1:n, diff_x2)
plt.plot((1, n), (e_x2, e_x2))
plt.plot((1, n), (e_x2*1.01, e_x2*1.01))
plt.plot((1, n), (e_x2*0.99, e_x2*0.99))
ylim(e_x2*0.98,e_x2*1.02)
title("Convergence of E[x^2]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x13549bb10>)
# PyObject <matplotlib.text.Text object at 0x1356d8ad0>

# %% [markdown]
# ## SMC Samplers

# %%
include("SMCSampler.jl")
n = int(1e6);
d = 5;
@time xs, w, essi = smcsampler(p, N=n, p = d, σ = 25.0);
x = reshape(xs[d,:], n);
# Out:
# elapsed time: 7
# .986094761 seconds (2491048432 bytes allocated, 19.65% gc time)

# %%
println(mean(x));
println(mean(x.^2));
g(x) = x.^2;
diff_x = fast_means(x);
diff_x2 = fast_means(x, g);
stable = stabalise(diff_x, e_x);
print(stable)
# Out:
# 4.
# 04770067205462
# 46.1801938863538
# 0.
# 040589516441548845125264

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("SMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1379a86d0>)
# PyObject <matplotlib.text.Text object at 0x11632f1d0>

# %%
plt.plot(1:n, diff_x)
plt.plot((1, n), (e_x, e_x))
plt.plot((1, n), (e_x*1.01, e_x*1.01))
plt.plot((1, n), (e_x*0.99, e_x*0.99))
plt.plot((stable, stable), (0, e_x*20))
ylim(e_x*0.98, e_x*1.02)
title("Convergence of E[x]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1164651d0>)
# PyObject <matplotlib.text.Text object at 0x116735050>

# %%
plt.plot(1:n, diff_x2)
plt.plot((1, n), (e_x2, e_x2))
plt.plot((1, n), (e_x2*1.01, e_x2*1.01))
plt.plot((1, n), (e_x2*0.99, e_x2*0.99))
ylim(e_x2*0.98,e_x2*1.02)
title("Convergence of E[x^2]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1168e5090>)
# PyObject <matplotlib.text.Text object at 0x116ec6310>

# %%
using Distributions: Normal, Uniform, pdf
using PyPlot
using Gadfly
include("mcmc.jl")
include("utils.jl")
include("SMCSampler.jl")
# Out:
# smcsampler (generic function with 1 method)

# %% [markdown]
# # Target distribution

# %%
p(x, alpha = 1.0) = (exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
p_dist(x, alpha = 1.0) = 1/((1.5+sqrt(2))*sqrt(pi))*(exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1));
plot([p], -5, 20)
# Out:
# Plot(...)

# %% [markdown]
# ## Ground Truth
# ### Wolfram Alpha
# ![Expected Value](ex.png)
# ![Expected Value](ex2.png)
#
# ### MCMC
# Estimated with $10^8$ samples
# $$\mu = 4.055412394948941$$
# $$E[x^2] = 46.20034183182638$$
# $$\sigma = 29.753972138720876$$

# %%
e_x = 4.05887;
e_x2 = 46.2633;

# %% [markdown]
# # MCMC

# %% [markdown]
# Get the samples...

# %%
srand(1236)
x0 = rand(); #starting position
n = int(1e6); #number of samples
@time x = mcmc(p, x0, n = n, stype = Float32, sig = 15);
# Out:
# elapsed time: 0.
# 691883218 seconds (104000160 bytes allocated, 22.07% gc time)

# %% [markdown]
# Plot the output

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("MCMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ff2f650>)
# PyObject <matplotlib.text.Text object at 0x11e1e8990>

# %% [markdown]
# ### Evaluate performance

# %%
println(mean(x));
println(mean(x.^2));
g(x) = x.^2;
diff_x = fast_means(x);
diff_x2 = fast_means(x, g);
# Out:
# 4.
# 0596705506911235
# 46.21261922786536

# %%
plt.plot(1:n, diff_x)
plt.plot((1, n), (e_x, e_x))
ylim(2,6)
title("Convergence of E[x]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11e237650>)
# PyObject <matplotlib.text.Text object at 0x120646710>

# %%
plt.plot(1:n, diff_x2)
plt.plot((1, n), (e_x2, e_x2))
ylim(20,80)
title("Convergence of E[x^2]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x12054f850>)
# PyObject <matplotlib.text.Text object at 0x1215adb90>

# %% [markdown]
# ## SMC Samplers

# %%
n = int(1e6);
d = 10;
@time xs, w, essi = smcsampler(p, N=n, p = d, σ = 25.0);
x = reshape(xs[d,:], n);
# Out:
# elapsed time: 1
# .365585895 seconds (312541632 bytes allocated, 5.72% gc time)
# elapsed time:
# 0.371901255 seconds (56000384 bytes allocated, 49.38% gc time)
# elapsed time:
# 20.201284612 seconds (5013303736 bytes allocated, 20.55% gc time)

# %%
println(mean(x));
println(mean(x.^2));
g(x) = x.^2;
diff_x = fast_means(x);
diff_x2 = fast_means(x, g);
# Out:
# 4.
# 080785634508824
# 46.567955420754224

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("SMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1215e4d90>)
# PyObject <matplotlib.text.Text object at 0x11de70690>

# %%
plt.plot(1:n, diff_x)
plt.plot((1, n), (e_x, e_x))
ylim(2,6)
title("Convergence of E[x]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11d1983d0>)
# PyObject <matplotlib.text.Text object at 0x11e30d950>

# %%
plt.plot(1:n, diff_x2)
plt.plot((1,n), (e_x2, e_x2))
ylim(20,80)
title("Convergence of E[x^2]")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x11def5e90>)
# PyObject <matplotlib.text.Text object at 0x124ba4dd0>

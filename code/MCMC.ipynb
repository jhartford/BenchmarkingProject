# %%
using Distributions: Normal, Uniform, pdf
using PyPlot
using Gadfly
# Out:
# INFO: Loading help data...

# %% [markdown]
# ## Simple MCMC

# %%
include("mcmc.jl")
# Out:
# mcmc (generic function with 1 method)

# %% [markdown]
# ### Target distribution

# %%
p(x, alpha = 1.0) = (exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
#p(x, alpha = 1.0) = (sin(1*x)^2*1/abs(0.1*x)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
plot([p], -25, 25)
# Out:
# Plot(...)

# %% [markdown]
# Get the samples...

# %%
x0 = rand(); #starting position
n = int(1e6); #number of samples
@time x = mcmc(p, x0, n = n, stype = Float32, sig = 5);
# Out:
# elapsed time: 1
# .717180136 seconds (104791408 bytes allocated, 45.34% gc time)

# %% [markdown]
# Plot the output

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("MCMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x122de0fd0>)
# PyObject <matplotlib.text.Text object at 0x1263687d0>

# %%
p(x, alpha = 1.0) = (exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
plot([p], -25, 25)

# %% [markdown]
# ## SMC Samplers

# %%
include("SMCSampler.jl")
N = int(1e6);
d = 10;
@time xs, w, essi = smcsampler(p, N=N, p = d, σ = 10.0);
x = reshape(xs[d,:], N);
# Out:
# elapsed time: 2
# .35871573 seconds (312003456 bytes allocated, 10.93% gc time)
# elapsed time:
# 0.891074671 seconds (56000384 bytes allocated, 78.99% gc time)
# elapsed time:
# 29.415400957 seconds (5012770584 bytes allocated, 25.12% gc time)

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("SMC output with $N samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x1208a0190>)
# PyObject <matplotlib.text.Text object at 0x123491150>

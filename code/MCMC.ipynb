# %%
using Distributions: Normal, Uniform, pdf
using PyPlot
using Gadfly
# Out:
# INFO: Loading help data...

# %% [markdown]
# ## Simple MCMC

# %%
include("mcmc.jl")
# Out:
# mcmc (generic function with 1 method)

# %% [markdown]
# ### Target distribution

# %%
p(x, alpha = 1.0) = (exp(-(x - 2).^2/2) + 0.5*exp(-(x+2).^2/1) + 0.5*exp(-(x-5).^2/1) + 0.5*exp(-(x-15).^2/1)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
#p(x, alpha = 1.0) = (sin(1*x)^2*1/abs(0.1*x)).^(alpha).*exp(-(x).^2/2).^(1-alpha);
plot([p], -25, 25)
# Out:
# Plot(...)

# %% [markdown]
# Get the samples...

# %%
x0 = rand(); #starting position
n = int(1e6); #number of samples
@time x = mcmc(p, x0, n = n, stype = Float32, sig = 5);
# Out:
# elapsed time: 0.
# 918788085 seconds (104577832 bytes allocated, 20.42% gc time)

# %% [markdown]
# Plot the output

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("MCMC output with $n samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x121ac2c10>)
# PyObject <matplotlib.text.Text object at 0x1227a3590>

# %% [markdown]
# ## SMC Samplers

# %%
include("SMCSampler.jl")
N = 1000000
d = 5
@time xs, w, essi = smcsampler(p, N=N, p = d, σ = 10.0);
x = reshape(xs[d,:], N);
# Out:
# elapsed time: 10
# .108852634 seconds (2491650072 bytes allocated, 19.64% gc time)

# %%
plt.hist(x,100, alpha=0.4, normed=true);
title("SMC output with $N samples")
# Out:
# Figure(PyObject <matplotlib.figure.Figure object at 0x12294c450>)
# PyObject <matplotlib.text.Text object at 0x122bd7c10>
